# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.feature_engineering import combine_columns
from src.recruiter import find_top_applicants_with_filters, retrieve_top_applicants

# %%
df = pd.read_parquet('data/processed/prospects.parquet')

# %%
df['codigo_list'] = df['prospects'].apply(lambda x: [item['codigo'] for item in x])
df['situacao_candidato'] = df['prospects'].apply(lambda x: [item['situacao_candidado'] for item in x])

# %%
df_exploded = df.explode(['codigo_list','situacao_candidato'])
df_exploded
# Out:
#       prospects_id                                             titulo  \
# 0             4530                                CONSULTOR CONTROL M
# 0             4530                                CONSULTOR CONTROL M
# 1             4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 1             4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 2             4532
# ...            ...                                                ...
# 14218        14219
# 14219        14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14219        14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14220        14221            Consultor Sênior Oracle EPM FCCS - 1434
# 14221        14222
#
#       modalidade                                          prospects  \
# 0                 [{'codigo': '25632', 'comentario': 'Encaminhad...
# 0                 [{'codigo': '25632', 'comentario': 'Encaminhad...
# 1                 [{'codigo': '25364', 'comentario': 'Data de In...
# 1                 [{'codigo': '25364', 'comentario': 'Data de In...
# 2                                                                []
# ...          ...                                                ...
# 14218                                                            []
# 14219             [{'codigo': '16828', 'comentario': 'Recebeu a ...
# 14219             [{'codigo': '16828', 'comentario': 'Recebeu a ...
# 14220             [{'codigo': '49190', 'comentario': '', 'data_c...
# 14221                                                            []
#
#       codigo_list           situacao_candidato
# 0           25632  Encaminhado ao Requisitante
# 0           25529  Encaminhado ao Requisitante
# 1           25364     Contratado pela Decision
# 1           25360  Encaminhado ao Requisitante
# 2             NaN                          NaN
# ...           ...                          ...
# 14218         NaN                          NaN
# 14219       16828                     Desistiu
# 14219       15042  Encaminhado ao Requisitante
# 14220       49190                     Prospect
# 14221         NaN                          NaN
#
# [56702 rows x 6 columns]

# %%
relevant_keywords = ['Encaminhado ao Requisitante', 'Contratado pela Decision',
       'Documentação PJ', 'Aprovado', 'Entrevista Técnica',
       'Em avaliação pelo RH', 'Contratado como Hunting',
       'Entrevista com Cliente','Documentação CLT', 'Documentação Cooperado',
       'Encaminhar Proposta',
       'Proposta Aceita']
df_exploded['relevant'] = df_exploded['situacao_candidato'].apply(lambda x: 1 if x in relevant_keywords else 0)

# %%
hired_keywords = [ 'Contratado pela Decision', 'Aprovado',
       'Contratado como Hunting', 'Encaminhar Proposta',
       'Proposta Aceita']
df_exploded['hired'] = df_exploded['situacao_candidato'].apply(lambda x: 1 if x in hired_keywords else 0)
df_exploded
# Out:
#       prospects_id                                             titulo  \
# 0             4530                                CONSULTOR CONTROL M
# 0             4530                                CONSULTOR CONTROL M
# 1             4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 1             4531  2021-2607395-PeopleSoft Application Engine-Dom...
# 2             4532
# ...            ...                                                ...
# 14218        14219
# 14219        14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14219        14220   Consultor Sênior Especialista SAP LES-TRA - 1433
# 14220        14221            Consultor Sênior Oracle EPM FCCS - 1434
# 14221        14222
#
#       modalidade                                          prospects  \
# 0                 [{'codigo': '25632', 'comentario': 'Encaminhad...
# 0                 [{'codigo': '25632', 'comentario': 'Encaminhad...
# 1                 [{'codigo': '25364', 'comentario': 'Data de In...
# 1                 [{'codigo': '25364', 'comentario': 'Data de In...
# 2                                                                []
# ...          ...                                                ...
# 14218                                                            []
# 14219             [{'codigo': '16828', 'comentario': 'Recebeu a ...
# 14219             [{'codigo': '16828', 'comentario': 'Recebeu a ...
# 14220             [{'codigo': '49190', 'comentario': '', 'data_c...
# 14221                                                            []
#
#       codigo_list           situacao_candidato  relevant  hired
# 0           25632  Encaminhado ao Requisitante         1      0
# 0           25529  Encaminhado ao Requisitante         1      0
# 1           25364     Contratado pela Decision         1      1
# 1           25360  Encaminhado ao Requisitante         1      0
# 2             NaN                          NaN         0      0
# ...           ...                          ...       ...    ...
# 14218         NaN                          NaN         0      0
# 14219       16828                     Desistiu         0      0
# 14219       15042  Encaminhado ao Requisitante         1      0
# 14220       49190                     Prospect         0      0
# 14221         NaN                          NaN         0      0
#
# [56702 rows x 8 columns]

# %%
df_exploded = df_exploded.rename(columns={'codigo_list':'applicant_id'
                            })

# %%
df_applicants = pd.read_parquet('data/processed/applicants.parquet')
applicants_columns_to_combine = [
    'titulo_profissional', 'objetivo_profissional', 'area_atuacao',
    'conhecimentos_tecnicos', 'certificacoes', 'nivel_profissional',
    'nivel_academico', 'cursos', 'cv_pt',
    'nivel_ingles', 'nivel_espanhol'
]
df_applicants = combine_columns(df_applicants, applicants_columns_to_combine)
df_applicants = df_applicants.rename(columns={'applicants_id':'applicant_id'})
df_exploded = df_exploded.merge(df_applicants[['applicant_id', 'text']], on='applicant_id', how='left')

# %%
df_exploded = df_exploded[['prospects_id','applicant_id','relevant','hired', 'text']].dropna(subset=['applicant_id']).rename(columns={'text':'applicants_text'})

# %%
df_jobs = pd.read_parquet('data/processed/vagas.parquet')

# %%
vagas_columns_to_combine = [
    'titulo_vaga', 'nivel profissional', 'nivel_academico',
    'nivel_ingles', 'nivel_espanhol', 'areas_atuacao',
    'principais_atividades', 'competencia_tecnicas_e_comportamentais',
    'habilidades_comportamentais_necessarias'
]

# %%
df_jobs = combine_columns(df_jobs, vagas_columns_to_combine)

# %%
df_jobs = df_jobs[['jobs_id','text']]

# %%
df_test = df_exploded.merge(df_jobs, left_on='prospects_id', right_on='jobs_id', how='left')

# %%
from src.embedding_manager import calculate_similarity
# Replace NaN values in the 'applicants_text' column with an empty string
df_test['applicants_text'] = df_test['applicants_text'].fillna('')
df_test['text'] = df_test['text'].fillna('')

# %%
df_test = df_test.sample(frac=0.1, random_state=42)

# %%
df_test.size
# Out:
# 37632

# %%
# Calculate similarity and save progress
df_temp = pd.DataFrame()
batch_size = 100  # Define the batch size for saving progress
for i in range(0, len(df_test), batch_size):
    df_test_batch = df_test.iloc[i:i+batch_size]
    df_test_batch['similarity'] = df_test_batch.apply(
        lambda row: calculate_similarity(row['text'], row['applicants_text']), axis=1
    )
    # Save the processed batch back to the main dataframe
    df_temp = pd.concat([df_temp, df_test_batch], ignore_index=True)
        # Save the intermediate results to a file
# Out:
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/1502727189.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_batch['similarity'] = df_test_batch.apply(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 6
#       4 for i in range(0, len(df_test), batch_size):
#       5     df_test_batch = df_test.iloc[i:i+batch_size]
# ----> 6     df_test_batch['similarity'] = df_test_batch.apply(
#       7         lambda row: calculate_similarity(row['text'], row['applicants_text']), axis=1
#       8     )
#       9     # Save the processed batch back to the main dataframe
#      10     df_temp = pd.concat([df_temp, df_test_batch], ignore_index=True)
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)  10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[37], line 7, in <lambda>(row)
#       4 for i in range(0, len(df_test), batch_size):
#       5     df_test_batch = df_test.iloc[i:i+batch_size]
#       6     df_test_batch['similarity'] = df_test_batch.apply(
# ----> 7         lambda row: calculate_similarity(row['text'], row['applicants_text']), axis=1
#       8     )
#       9     # Save the processed batch back to the main dataframe
#      10     df_temp = pd.concat([df_temp, df_test_batch], ignore_index=True)
#
# File ~/Desktop/Dataton/src/embedding_manager.py:43, in calculate_similarity(text1, text2)
#      39 def calculate_similarity(text1: str, text2: str) -> float:
#      40     """
#      41     Calculate the cosine similarity between two texts.
#      42     """
# ---> 43     manager = EmbeddingManager()
#      44     embedding1 = manager.generate_embedding(text1)
#      45     embedding2 = manager.generate_embedding(text2)
#
# File ~/Desktop/Dataton/src/embedding_manager.py:14, in EmbeddingManager.__init__(self, config_path)
#      13 def __init__(self, config_path: str = "models_config.yaml"):
# ---> 14     self.model = EmbeddingModel(config_path)
#
# File ~/Desktop/Dataton/src/embedding_manager.py:33, in EmbeddingModel.__init__(self, config_path)
#      31     config = yaml.safe_load(file)
#      32 self.model_name = config['embedding_model']['name']
# ---> 33 self.model = SentenceTransformer(self.model_name)
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/sentence_transformers/SentenceTransformer.py:327, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)    314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)    325     == self._model_config["model_type"]
#     326 ):
# --> 327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#     330         cache_folder=cache_folder,
#     331         revision=revision,
#     332         trust_remote_code=trust_remote_code,
#     333         local_files_only=local_files_only,
#     334         model_kwargs=model_kwargs,
#     335         tokenizer_kwargs=tokenizer_kwargs,
#     336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#     339     modules = self._load_auto_model(
#     340         model_name_or_path,
#     341         token=token,
#    (...)    349         has_modules=has_modules,
#     350     )
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/sentence_transformers/SentenceTransformer.py:2305, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    2300         module = module_class.load(local_path)
#    2302 else:
#    2303     # Newer modules that support the new loading method are loaded with the new style
#    2304     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 2305     module = module_class.load(
#    2306         model_name_or_path,
#    2307         # Loading-specific keyword arguments
#    2308         subfolder=module_config["path"],
#    2309         token=token,
#    2310         cache_folder=cache_folder,
#    2311         revision=revision,
#    2312         local_files_only=local_files_only,
#    2313         # Module-specific keyword arguments
#    2314         trust_remote_code=trust_remote_code,
#    2315         model_kwargs=model_kwargs,
#    2316         tokenizer_kwargs=tokenizer_kwargs,
#    2317         config_kwargs=config_kwargs,
#    2318         backend=self.backend,
#    2319     )
#    2321 modules[module_config["name"]] = module
#    2322 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/sentence_transformers/models/Transformer.py:365, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, tokenizer_kwargs, config_kwargs, backend, **kwargs)
#     334 @classmethod
#     335 def load(
#     336     cls,
#    (...)    350     **kwargs,
#     351 ) -> Self:
#     352     init_kwargs = cls._load_init_kwargs(
#     353         model_name_or_path=model_name_or_path,
#     354         subfolder=subfolder,
#    (...)    363         backend=backend,
#     364     )
# --> 365     return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/sentence_transformers/models/Transformer.py:102, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#     100 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#     101     tokenizer_args["model_max_length"] = max_seq_length
# --> 102 self.tokenizer = AutoTokenizer.from_pretrained(
#     103     tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path,
#     104     cache_dir=cache_dir,
#     105     **tokenizer_args,
#     106 )
#     108 # No max_seq_length set. Try to infer from model
#     109 if max_seq_length is None:
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/transformers/models/auto/tokenization_auto.py:1125, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1121     if tokenizer_class is None:
#    1122         raise ValueError(
#    1123             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#    1124         )
# -> 1125     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1127 # Otherwise we have to be creative.
#    1128 # if model is an encoder decoder, the encoder tokenizer class is used by default
#    1129 if isinstance(config, EncoderDecoderConfig):
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2012, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2008             vocab_files[f"chat_template_{template_name}"] = (
#    2009                 f"{CHAT_TEMPLATE_DIR}/{template_file.name}"
#    2010             )
#    2011 else:
# -> 2012     for template in list_repo_templates(
#    2013         pretrained_model_name_or_path,
#    2014         local_files_only=local_files_only,
#    2015         revision=revision,
#    2016         cache_dir=cache_dir,
#    2017     ):
#    2018         template = template.removesuffix(".jinja")
#    2019         vocab_files[f"chat_template_{template}"] = f"{CHAT_TEMPLATE_DIR}/{template}.jinja"
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/transformers/utils/hub.py:169, in list_repo_templates(repo_id, local_files_only, revision, cache_dir)
#     165 if not local_files_only:
#     166     try:
#     167         return [
#     168             entry.path.removeprefix(f"{CHAT_TEMPLATE_DIR}/")
# --> 169             for entry in list_repo_tree(
#     170                 repo_id=repo_id,
#     171                 revision=revision,
#     172                 path_in_repo=CHAT_TEMPLATE_DIR,
#     173                 recursive=False,
#     174             )
#     175             if entry.path.endswith(".jinja")
#     176         ]
#     177     except (GatedRepoError, RepositoryNotFoundError, RevisionNotFoundError):
#     178         raise  # valid errors => do not catch
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/huggingface_hub/hf_api.py:3188, in HfApi.list_repo_tree(self, repo_id, path_in_repo, recursive, expand, revision, repo_type, token)
#    3186 encoded_path_in_repo = "/" + quote(path_in_repo, safe="") if path_in_repo else ""
#    3187 tree_url = f"{self.endpoint}/api/{repo_type}s/{repo_id}/tree/{revision}{encoded_path_in_repo}"
# -> 3188 for path_info in paginate(path=tree_url, headers=headers, params={"recursive": recursive, "expand": expand}):
#    3189     yield (RepoFile(**path_info) if path_info["type"] == "file" else RepoFolder(**path_info))
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/huggingface_hub/utils/_pagination.py:36, in paginate(path, params, headers)
#      28 """Fetch a list of models/datasets/spaces and paginate through results.
#      29
#      30 This is using the same "Link" header format as GitHub.
#    (...)     33 - https://docs.github.com/en/rest/guides/traversing-with-pagination#link-header
#      34 """
#      35 session = get_session()
# ---> 36 r = session.get(path, params=params, headers=headers)
#      37 hf_raise_for_status(r)
#      38 yield from r.json()
#
# File ~/.local/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:95, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      93     logger.debug(f"Send: {_curlify(request)}")
#      94 try:
# ---> 95     return super().send(request, *args, **kwargs)
#      96 except requests.RequestException as e:
#      97     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/.local/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/.local/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/miniconda3/envs/fiap_env/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_temp
# Out:
#     prospects_id applicant_id  relevant  hired  \
# 0           1938        18301         1      0
# 1           9754        37578         1      0
# 2           1127        14978         1      0
# 3           8799        34486         0      0
# 4          12392        26568         0      0
# ..           ...          ...       ...    ...
# 695        11670        17912         1      0
# 696         4209        22192         0      0
# 697         3740        22905         1      0
# 698         5547        27311         0      0
# 699         7067        16792         0      0
#
#                                        applicants_text jobs_id  \
# 0    titulo_profissional:  objetivo_profissional:  ...    1938
# 1    titulo_profissional: Android/IOS objetivo_prof...    9754
# 2    titulo_profissional:  objetivo_profissional:  ...    1127
# 3    titulo_profissional: Desenvolvedor IOS objetiv...    8799
# 4    titulo_profissional: Consultor SAP PP QM objet...   12392
# ..                                                 ...     ...
# 695  titulo_profissional:  objetivo_profissional:  ...   11670
# 696  titulo_profissional:  objetivo_profissional:  ...    4209
# 697                                                       3740
# 698  titulo_profissional: Consultor Oracle, Analist...    5547
# 699  titulo_profissional: Analista de Suporte Infra...    7067
#
#                                                   text  similarity
# 0    titulo_vaga: SAP ABAP - 20207041623 nivel prof...    0.726363
# 1    titulo_vaga: Software Developer (iOS or Androi...    0.591533
# 2    titulo_vaga: Desenvolvedor .Net (TypeScript) -...    0.533866
# 3    titulo_vaga: Android Dev - Senior nivel profis...    0.641164
# 4    titulo_vaga: SAP PP/QM - SV-124 nivel profissi...    0.781615
# ..                                                 ...         ...
# 695  titulo_vaga: SAP ABAP/PI nivel profissional: A...    0.803015
# 696  titulo_vaga: Senior DevOps Engineer nivel prof...    0.521762
# 697  titulo_vaga: Desenvolvedor Web .Net/C# - Junio...    0.015633
# 698  titulo_vaga: Analista Sistema Oracle Sênior. n...    0.724671
# 699  titulo_vaga: Prop - Analista Windows Pl/Sr niv...    0.661828
#
# [700 rows x 8 columns]

# %%
df_grouped = df_temp.groupby('prospects_id').agg(
    applicant_id = ("applicant_id", list),
    num_applicants = ('applicant_id', 'count'),
    relevant = ('relevant', list),
    hired = ('hired', list),
    text = ('text', 'first'),
    mean_similarity = ('similarity', list),
).reset_index()

# %%
from src.recruiter import RecruiterBot
import os, sys, yaml
from src.embedding_manager import EmbeddingManager
from src.indexer import FAISSIndexer

with open(os.path.join( "src", "config", "index_config.yaml")) as f:
    index_cfg = yaml.safe_load(f)
emb_mgr = EmbeddingManager(config_path=os.path.join( "models_config.yaml"))
indexer = FAISSIndexer(index_cfg)
# load your applicants_df here (parquet/csv)
bot = RecruiterBot( emb_mgr, indexer)

# %%
df_grouped['top_applicants'] = df_grouped.apply(lambda row:find_top_applicants_with_filters(
                job_description=row['text'],
                faiss_indexer=indexer,
                emb_mgr=emb_mgr,
                filters={},
                top_n=row['num_applicants']), axis=1)

# %%
df_grouped['top_applicants_ids'] = df_grouped['top_applicants'].apply(lambda x: [item['applicant_id'] for item in x if 'metadata' in item and 'jobs_id' in item['metadata']])
df_grouped['top_applicants_scores'] = df_grouped['top_applicants'].apply(lambda x: [item['score'] for item in x if 'score' in item])

# %%
df_grouped.head(1)
# Out:
#   prospects_id applicant_id  num_applicants relevant hired  \
# 0        10002      [38343]               1      [1]   [0]
#
#                                                 text       mean_similarity  \
# 0  titulo_vaga: Salesforce / Desenvolvedor 132712...  [0.6670516729354858]
#
#                                       top_applicants top_applicants_ids  \
# 0  [{'applicant_idx': 4127, 'applicant_id': '1117...            [11178]
#
#   top_applicants_scores
# 0  [1.0000001192092896]

# %%
df_validation = df_grouped[['prospects_id','applicant_id','top_applicants_ids','relevant','hired', 'mean_similarity', 'top_applicants_scores']]

# %%
df_validation['hired_similarity'] = df_validation.apply(
	lambda row: [applicant_id for hired, applicant_id in zip(row['hired'], row['mean_similarity']) if hired == 1],
	axis=1
)
df_validation['relevant_similarity'] = df_validation.apply(
	lambda row: [applicant_id for relevant, applicant_id in zip(row['relevant'], row['mean_similarity']) if relevant == 1],
	axis=1
)
# Out:
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/3835521252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_validation['hired_similarity'] = df_validation.apply(
# /var/folders/9l/ssjsy50d6vqb5mscfhwxj6h80000gp/T/ipykernel_7068/3835521252.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_validation['relevant_similarity'] = df_validation.apply(

# %%
df_validation.head(1)
# Out:
#   prospects_id applicant_id top_applicants_ids relevant hired  \
# 0        10002      [38343]            [11178]      [1]   [0]
#
#         mean_similarity top_applicants_scores hired_similarity  \
# 0  [0.6670516729354858]  [1.0000001192092896]               []
#
#     relevant_similarity
# 0  [0.6670516729354858]

# %% [markdown]
# ## calculate score relevant and hired

# %%
df_validation['mean_prospects_similarity'] = df_validation['mean_similarity'].apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)
df_validation['mean_top_applicants_score'] = df_validation['top_applicants_scores'].apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)
df_validation['mean_hired_similarity'] = df_validation['hired_similarity'].apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)
df_validation['mean_relevant_similarity'] = df_validation['relevant_similarity'].apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)

# %%
df_validation = df_validation[['prospects_id', 'applicant_id', 'top_applicants_ids',  'mean_prospects_similarity',
       'mean_top_applicants_score', 'mean_hired_similarity',
       'mean_relevant_similarity']]

# %%
df_validation.to_parquet('data/processed/validation.parquet', index=False)

# %%
print(f"Mean hired similarity: {df_validation['mean_hired_similarity'].mean():.4f}")
print(f"Mean relevant similarity: {df_validation['mean_relevant_similarity'].mean():.4f}")
print(f"Mean prospects similarity: {df_validation['mean_prospects_similarity'].mean():.4f}")
print(f"Mean top applicants score: {df_validation['mean_top_applicants_score'].mean():.4f}")
# Out:
# Mean hired similarity: 0.0404
# Mean relevant similarity: 0.2210
# Mean prospects similarity: 0.5337
# Mean top applicants score: 1.0000
